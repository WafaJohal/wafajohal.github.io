# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "proceedings.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    }#,
   # "journal":{
   #     "file": "pubs.bib",
   #     "venuekey" : "journal",
   #     "venue-pretext" : "",
   #     "collection" : {"name":"publications",
   #                     "permalink":"/publication/"}
   # } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        print("==========")
        print(bib_id)
        abstract = ""
        keywords=""
        
        b = bibdata.entries[bib_id].fields

        print(bibdata.entries[bib_id])
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

            if "abstract" in b.keys():
                abstract = b["abstract"]

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            #else:
            #    md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"
            md+="**Abstract**:"
            md+=abstract

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# ==========
# benkaouar2012multi
# Entry('inproceedings',
#   fields=[
#     ('title', 'Multi-sensors engagement detection with a robot companion in a home environment'),
#     ('year', '2012')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Benkaouar, Wafa'), Person('Vaufreydaz, Dominique')])]))
# WARNING Missing Expected Field 'booktitle' from entry benkaouar2012multi: " Multi-sensors engagement detec ... "
# ==========
# johal2013modelling
# Entry('inproceedings',
#   fields=[
#     ('title', 'Modelling interactions in a mixed agent world.'),
#     ('booktitle', 'European Modeling and Simulation Symposium'),
#     ('year', '2013')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Dugdale, Julie'), Person('Pesty, Sylvie')])]))
# SUCESSFULLY PARSED johal2013modelling: " Modelling interactions in a mixed agent world.  "
# ==========
# adam2013acceptabilite
# Entry('inproceedings',
#   fields=[
#     ('title', "Acceptabilit{\\'e} d'un robot compagnon dans des situations de la vie quotidienne."),
#     ('booktitle', "Deuxi{\\`e}me conf{\\'e}rence III - Intercompr{\\'e}hension de l'intrasp{\\'e}cifique {\\`a} l'intersp{\\'e}cifique"),
#     ('year', '2013')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Adam, Carole'), Person('Johal, Wafa'), Person('Ben Farhat, Ilef'), Person("Jost, C{\\'e}line"), Person('Fiorono, Humbert'), Person('Pesty, Sylvie'), Person('Duhaut, Dominique')])]))
# SUCESSFULLY PARSED adam2013acceptabilite: " Acceptabilit{\'e} d'un robot compagnon dans des situations d ... "
# ==========
# johal2014robot
# Entry('inproceedings',
#   fields=[
#     ('title', 'A Robot with Style, because you are Worth it!'),
#     ('booktitle', 'Proceedings of the extended abstracts of the 32nd annual ACM conference on Human factors in computing systems'),
#     ('pages', '1201--1206'),
#     ('year', '2014'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Calvary, Gaelle'), Person('Pesty, Sylvie')])]))
# SUCESSFULLY PARSED johal2014robot: " A Robot with Style, because you are Worth it!  "
# ==========
# johal2014expressing
# Entry('inproceedings',
#   fields=[
#     ('title', 'Expressing Parenting Styles with Companion Robots'),
#     ('booktitle', 'Workshop on Applications for Emotional Robots, Human Robot Interaction (HRI) 2014'),
#     ('year', '2014')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Pesty, Sylvie'), Person('Calvary, Ga{\\"e}lle')])]))
# SUCESSFULLY PARSED johal2014expressing: " Expressing Parenting Styles with Companion Robots  "
# ==========
# johal2014towards
# Entry('inproceedings',
#   fields=[
#     ('title', 'Towards companion robots behaving with style'),
#     ('booktitle', 'The 23rd IEEE International Symposium on Robot and Human Interactive Communication'),
#     ('pages', '1063--1068'),
#     ('year', '2014'),
#     ('organization', 'IEEE')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Pesty, Sylvie'), Person('Calvary, Gaelle')])]))
# SUCESSFULLY PARSED johal2014towards: " Towards companion robots behaving with style  "
# ==========
# vaufreydaz2016starting
# Entry('article',
#   fields=[
#     ('title', 'Starting engagement detection towards a companion robot using multimodal features'),
#     ('journal', 'Robotics and Autonomous Systems'),
#     ('volume', '75'),
#     ('pages', '4--16'),
#     ('year', '2016'),
#     ('publisher', 'North-Holland')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Vaufreydaz, Dominique'), Person('Johal, Wafa'), Person('Combe, Claudine')])]))
# WARNING Missing Expected Field 'booktitle' from entry vaufreydaz2016starting: " Starting engagement detection  ... "
# ==========
# johal2014acceptability
# Entry('inproceedings',
#   fields=[
#     ('title', 'Acceptability of a companion robot for children in daily life situations'),
#     ('booktitle', '2014 5th IEEE Conference on Cognitive Infocommunications (CogInfoCom)'),
#     ('pages', '31--36'),
#     ('year', '2014'),
#     ('organization', 'IEEE')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Adam, Carole'), Person('Fiorino, Humbert'), Person('Pesty, Sylvie'), Person("Jost, C{\\'e}line"), Person('Duhaut, Dominique')])]))
# SUCESSFULLY PARSED johal2014acceptability: " Acceptability of a companion robot for children in daily lif ... "
# ==========
# johal2014styles
# Entry('article',
#   fields=[
#     ('title', "Des Styles pour une Personnalisation de l'Interaction Homme-Robot"),
#     ('year', '2014')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Pesty, Sylvie'), Person('Calvary, Ga{\\"e}lle')])]))
# WARNING Missing Expected Field 'booktitle' from entry johal2014styles: " Des Styles pour une Personnali ... "
# ==========
# johal2015robots
# Entry('inproceedings',
#   fields=[
#     ('title', 'Robots Interacting with Style'),
#     ('booktitle', 'Proceedings of the Tenth Annual ACM/IEEE International Conference on Human-Robot Interaction Extended Abstracts'),
#     ('pages', '191--192'),
#     ('year', '2015'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa')])]))
# SUCESSFULLY PARSED johal2015robots: " Robots Interacting with Style  "
# ==========
# johal2015cognitive
# Entry('inproceedings',
#   fields=[
#     ('title', 'A cognitive and affective architecture for social human-robot interaction'),
#     ('booktitle', 'Proceedings of the Tenth Annual ACM/IEEE International Conference on Human-Robot Interaction Extended Abstracts'),
#     ('pages', '71--72'),
#     ('year', '2015'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Pellier, Damien'), Person('Adam, Carole'), Person('Fiorino, Humbert'), Person('Pesty, Sylvie')])]))
# SUCESSFULLY PARSED johal2015cognitive: " A cognitive and affective architecture for social human-robo ... "
# ==========
# ta2015grenoble
# Entry('inproceedings',
#   fields=[
#     ('title', 'The Grenoble system for the social touch challenge at ICMI 2015'),
#     ('booktitle', 'Proceedings of the 2015 ACM on International Conference on Multimodal Interaction'),
#     ('pages', '391--398'),
#     ('year', '2015'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Ta, Viet-Cuong'), Person('Johal, Wafa'), Person('Portaz, Maxime'), Person('Castelli, Eric'), Person('Vaufreydaz, Dominique')])]))
# SUCESSFULLY PARSED ta2015grenoble: " The Grenoble system for the social touch challenge at ICMI 2 ... "
# ==========
# johal2015non
# Entry('inproceedings',
#   fields=[
#     ('title', 'Non-verbal Signals in HRI: Interference in Human Perception'),
#     ('booktitle', 'International Conference on Social Robotics'),
#     ('pages', '275--284'),
#     ('year', '2015'),
#     ('organization', 'Springer, Cham')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Calvary, Ga{\\"e}lle'), Person('Pesty, Sylvie')])]))
# SUCESSFULLY PARSED johal2015non: " Non-verbal Signals in HRI: Interference in Human Perception  "
# ==========
# ozgur2016permanent
# Entry('inproceedings',
#   fields=[
#     ('title', 'Permanent magnet-assisted omnidirectional ball drive'),
#     ('booktitle', '2016 IEEE/RSJ International Conference on Intelligent Robots and Systems (IROS)'),
#     ('pages', '1061--1066'),
#     ('year', '2016'),
#     ('organization', 'IEEE')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{\\"O}zg{\\"u}r, Ayberk'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED ozgur2016permanent: " Permanent magnet-assisted omnidirectional ball drive  "
# ==========
# jacq2016cognitive
# Entry('article',
#   fields=[
#     ('title', 'Cognitive architecture for mutual modelling'),
#     ('journal', 'arXiv preprint arXiv:1602.06703'),
#     ('year', '2016')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Jacq, Alexis'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre'), Person('Paiva, Ana')])]))
# WARNING Missing Expected Field 'booktitle' from entry jacq2016cognitive: " Cognitive architecture for mut ... "
# ==========
# johal2016child
# Entry('inproceedings',
#   fields=[
#     ('title', 'Child-robot spatial arrangement in a learning by teaching activity'),
#     ('booktitle', '2016 25th IEEE International Symposium on Robot and Human Interactive Communication (RO-MAN)'),
#     ('pages', '533--538'),
#     ('year', '2016'),
#     ('organization', 'Ieee')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Jacq, Alexis'), Person('Paiva, Ana'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED johal2016child: " Child-robot spatial arrangement in a learning by teaching ac ... "
# ==========
# pellier2018architecture
# Entry('article',
#   fields=[
#     ('title', 'Une architecture cognitive et affective oriente interaction'),
#     ('journal', 'arXiv preprint arXiv:1810.10909'),
#     ('year', '2018')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Pellier, Damien'), Person('Adam, Carole'), Person('Johal, Wafa'), Person('Fiorino, Humbert'), Person('Pesty, Sylvie')])]))
# WARNING Missing Expected Field 'booktitle' from entry pellier2018architecture: " Une architecture cognitive et  ... "
# ==========
# adam2016social
# Entry('inproceedings',
#   fields=[
#     ('title', 'Social human-robot interaction: A new cognitive and affective interaction-oriented architecture'),
#     ('booktitle', 'International conference on social robotics'),
#     ('pages', '253--263'),
#     ('year', '2016'),
#     ('organization', 'Springer, Cham')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Adam, Carole'), Person('Johal, Wafa'), Person('Pellier, Damien'), Person('Fiorino, Humbert'), Person('Pesty, Sylvie')])]))
# SUCESSFULLY PARSED adam2016social: " Social human-robot interaction: A new cognitive and affectiv ... "
# ==========
# mondada2016r2t2
# Entry('article',
#   fields=[
#     ('title', 'R2T2: Robotics to integrate educational efforts in South Africa and Europe'),
#     ('journal', 'International Journal of Advanced Robotic Systems'),
#     ('volume', '13'),
#     ('number', '5'),
#     ('pages', '1729881416658165'),
#     ('year', '2016'),
#     ('publisher', 'SAGE Publications Sage UK: London, England')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Mondada, Francesco'), Person('Bonnet, Evgeniia'), Person('Davrajh, Shaniel'), Person('Johal, Wafa'), Person('Stopforth, Riaan')])]))
# WARNING Missing Expected Field 'booktitle' from entry mondada2016r2t2: " R2T2: Robotics to integrate ed ... "
# ==========
# ozgur2017windfield
# Entry('inproceedings',
#   fields=[
#     ('title', 'Windfield: learning wind meteorology with handheld haptic robots'),
#     ('booktitle', 'Proceedings of the 2017 ACM/IEEE International Conference on Human-Robot Interaction'),
#     ('pages', '156--165'),
#     ('year', '2017'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{\\"O}zg{\\"u}r, Ayberk'), Person('Johal, Wafa'), Person('Mondada, Francesco'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED ozgur2017windfield: " Windfield: learning wind meteorology with handheld haptic ro ... "
# ==========
# ozgur2017cellulo
# Entry('inproceedings',
#   fields=[
#     ('title', 'Cellulo: Versatile handheld robots for education'),
#     ('booktitle', '2017 12th ACM/IEEE International Conference on Human-Robot Interaction (HRI'),
#     ('pages', '119--127'),
#     ('year', '2017'),
#     ('organization', 'IEEE')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{\\"O}zg{\\"u}r, Ayberk'), Person("Lemaignan, S{\\'e}verin"), Person('Johal, Wafa'), Person('Beltran, Maria'), Person('Briod, Manon'), Person("Pereyre, L{\\'e}a"), Person('Mondada, Francesco'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED ozgur2017cellulo: " Cellulo: Versatile handheld robots for education  "
# ==========
# ozgur2017haptic
# Entry('inproceedings',
#   fields=[
#     ('title', 'Haptic-enabled handheld mobile robots: Design and analysis'),
#     ('booktitle', 'Proceedings of the 2017 CHI Conference on Human Factors in Computing Systems'),
#     ('pages', '2449--2461'),
#     ('year', '2017'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{\\"O}zg{\\"u}r, Ayberk'), Person('Johal, Wafa'), Person('Mondada, Francesco'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED ozgur2017haptic: " Haptic-enabled handheld mobile robots: Design and analysis  "
# ==========
# ozgur2017windfielddemo
# Entry('inproceedings',
#   fields=[
#     ('title', 'Windfield: demonstrating wind meteorology with handheld haptic robots'),
#     ('booktitle', 'Proceedings of the Companion of the 2017 ACM/IEEE International Conference on Human-Robot Interaction'),
#     ('pages', '48--49'),
#     ('year', '2017'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{\\"O}zg{\\"u}r, Ayberk'), Person('Johal, Wafa'), Person('Mondada, Francesco'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED ozgur2017windfielddemo: " Windfield: demonstrating wind meteorology with handheld hapt ... "
# ==========
# johal2017workshop
# Entry('inproceedings',
#   fields=[
#     ('title', 'Workshop on Robots for Learning: R4L'),
#     ('booktitle', 'Proceedings of the Companion of the 2017 ACM/IEEE International Conference on Human-Robot Interaction'),
#     ('pages', '423--424'),
#     ('year', '2017'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Vogt, Paul'), Person('Kennedy, James'), Person('de Haas, Mirjam'), Person('Paiva, Ana'), Person('Castellano, Ginevra'), Person('Okita, Sandra'), Person('Tanaka, Fumihide'), Person('Belpaeme, Tony'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED johal2017workshop: " Workshop on Robots for Learning: R4L  "
# ==========
# asselborn2017keep
# Entry('inproceedings',
#   fields=[
#     ('title', 'Keep on moving! Exploring anthropomorphic effects of motion during idle moments'),
#     ('booktitle', '2017 26th IEEE International Symposium on Robot and Human Interactive Communication (RO-MAN)'),
#     ('pages', '897--902'),
#     ('year', '2017'),
#     ('organization', 'IEEE')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Asselborn, Thibault'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED asselborn2017keep: " Keep on moving! Exploring anthropomorphic effects of motion  ... "
# ==========
# johal2015companion
# Entry('phdthesis',
#   fields=[
#     ('title', 'Companion Robots Behaving with Style: Towards Plasticity in Social Human-Robot Interaction'),
#     ('year', '2015')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa Benkaouar')])]))
# WARNING Missing Expected Field 'booktitle' from entry johal2015companion: " Companion Robots Behaving with ... "
# ==========
# jacq2017expressing
# Entry('techreport',
#   fields=[
#     ('title', 'Expressing Motivations By Facilitating Other’s Inverse Reinforcement Learning'),
#     ('year', '2017'),
#     ('institution', 'Instituto Superiro Technico')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Jacq, Alexis David'), Person('Johal, Wafa'), Person('Paiva, Ana'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'booktitle' from entry jacq2017expressing: " Expressing Motivations By Faci ... "
# ==========
# guneysu2018iterative
# Entry('inproceedings',
#   fields=[
#     ('title', 'Iterative design of an upper limb rehabilitation game with tangible robots'),
#     ('booktitle', 'Proceedings of the 2018 ACM/IEEE International Conference on Human-Robot Interaction'),
#     ('pages', '241--250'),
#     ('year', '2018'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Guneysu Ozgur, Arzu'), Person('Wessel, Maximilian Jonas'), Person('Johal, Wafa'), Person('Sharma, Kshitij'), Person('{\\"O}zg{\\"u}r, Ayberk'), Person('Vuadens, Philippe'), Person('Mondada, Francesco'), Person('Hummel, Friedhelm Christoph'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED guneysu2018iterative: " Iterative design of an upper limb rehabilitation game with t ... "
# ==========
# johal2018robots
# Entry('inproceedings',
#   fields=[
#     ('title', 'Robots for Learning-R4L: Inclusive Learning'),
#     ('booktitle', 'Companion of the 2018 ACM/IEEE International Conference on Human-Robot Interaction'),
#     ('pages', '397--398'),
#     ('year', '2018'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Kennedy, James'), Person('Charisi, Vicky'), Person('Park, Hae Won'), Person('Castellano, Ginevra'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED johal2018robots: " Robots for Learning-R4L: Inclusive Learning  "
# ==========
# guneysutangible
# Entry('article',
#   fields=[
#     ('title', 'Tangible Robots Mediated Collaborative Rehabilitation Design: Can we Find Inspiration from Scripting Collaborative Learning?'),
#     ('journal', 'Robots for Learning Workshop on Inclusive Learning'),
#     ('year', '2018')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Guneysu, Arzu'), Person('Johal, Wafa'), Person('Ozgur, Ayberk'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'booktitle' from entry guneysutangible: " Tangible Robots Mediated Colla ... "
# ==========
# yadollahi2018deictic
# Entry('inproceedings',
#   fields=[
#     ('title', 'When deictic gestures in a robot can harm child-robot collaboration'),
#     ('booktitle', 'Proceedings of the 17th ACM Conference on Interaction Design and Children'),
#     ('pages', '195--206'),
#     ('year', '2018'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Yadollahi, Elmira'), Person('Johal, Wafa'), Person('Paiva, Ana'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED yadollahi2018deictic: " When deictic gestures in a robot can harm child-robot collab ... "
# ==========
# asselborn2018bringing
# Entry('inproceedings',
#   fields=[
#     ('title', 'Bringing letters to life: handwriting with haptic-enabled tangible robots'),
#     ('booktitle', 'Proceedings of the 17th ACM Conference on Interaction Design and Children'),
#     ('pages', '219--230'),
#     ('year', '2018'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Asselborn, Thibault'), Person('Guneysu, Arzu'), Person('Mrini, Khalil'), Person('Yadollahi, Elmira'), Person('Ozgur, Ayberk'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED asselborn2018bringing: " Bringing letters to life: handwriting with haptic-enabled ta ... "
# ==========
# charisi2018near
# Entry('inproceedings',
#   fields=[
#     ('title', "The near future of children's robotics"),
#     ('booktitle', 'Proceedings of the 17th ACM Conference on Interaction Design and Children'),
#     ('pages', '720--727'),
#     ('year', '2018'),
#     ('organization', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Charisi, Vicky'), Person('Alcorn, Alyssa M'), Person('Kennedy, James'), Person('Johal, Wafa'), Person('Baxter, Paul'), Person('Kynigos, Chronis')])]))
# SUCESSFULLY PARSED charisi2018near: " The near future of children's robotics  "
# ==========
# jacqnon
# Entry('article',
#   fields=[
#     ('title', 'Non-recursive Approach for Mutual Understanding'),
#     ('year', '2016'),
#     ('journal', 'Journée de travail sur la robotique interactive et cognitive')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Jacq, Alexis'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'booktitle' from entry jacqnon: " Non-recursive Approach for Mut ... "
# ==========
# asselborn2018automated
# Entry('article',
#   fields=[
#     ('title', 'Automated human-level diagnosis of dysgraphia using a consumer tablet'),
#     ('journal', 'npj Digital Medicine'),
#     ('volume', '1'),
#     ('number', '1'),
#     ('pages', '42'),
#     ('year', '2018'),
#     ('publisher', 'Nature Publishing Group')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Asselborn, Thibault'), Person('Gargot, Thomas'), Person("Kidzi{\\'n}ski, {\\L}ukasz"), Person('Johal, Wafa'), Person('Cohen, David'), Person('Jolly, Caroline'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'booktitle' from entry asselborn2018automated: " Automated human-level diagnosi ... "
# ==========
# 8857508
# Entry('inproceedings',
#   fields=[
#     ('bo
#     oktitle', '2019 41st Annual International Conference of the IEEE Engineering in Medicine and Biology Society (EMBC)'), ('title', 'Designing Configurable Arm Rehabilitation Games: How Do Different Game Elements Affect User Motion Trajectories?'),
#     ('year', '2019'),
#     ('volume', ''),
#     ('number', ''),
#     ('doi', '10.1109/EMBC.2019.8857508'),
#     ('pages', '5326-5330')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{Ozgur}, A. G.'), Person('{Wessel}, M. J.'), Person('{Asselborn}, T.'), Person('{Olsen}, J. K.'), Person('{Johal}, W.'), Person('{Özgür}, A.'), Person('{Hummel}, F. C.'), Person('{Dillenbourg}, P.')])]))
# SUCESSFULLY PARSED 8857508: " Designing Configurable Arm Rehabilitation Games: How Do Diff ... "
# ==========
# ozgur2018declarative
# Entry('inproceedings',
#   fields=[
#     ('title', 'Declarative Physicomimetics for Tangible Swarm Application Development'),
#     ('booktitle', 'Proceedings of the 11th International Conference on Swarm Intelligence, ANTS 2018'),
#     ('volume', '11172'),
#     ('number', 'CONF'),
#     ('year', '2018')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{\\"O}zg{\\"u}r, Ayberk'), Person('Johal, Wafa'), Person('G{\\"u}neysu {\\"O}zg{\\"u}r, Arzu'), Person('Mondada, Francesco'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED ozgur2018declarative: " Declarative Physicomimetics for Tangible Swarm Application D ... "
# ==========
# ozgur2019magnet
# Entry('misc',
#   fields=[
#     ('title', 'Magnet-assisted ball drive'),
#     ('year', '2019'),
#     ('month', 'January~17'),
#     ('note', 'US Patent App. 15/648,425')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{\\"O}zg{\\"u}r, Ayberk'), Person("Lemaignan, S{\\'e}verin"), Person('Johal, Wafa'), Person('Mondada, Francesco'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'booktitle' from entry ozgur2019magnet: " Magnet-assisted ball drive  "
# ==========
# johal2019robots
# Entry('inproceedings',
#   fields=[
#     ('title', 'Robots for Learning-R4L: Adaptive Learning'),
#     ('booktitle', '2019 14th ACM/IEEE International Conference on Human-Robot Interaction (HRI)'),
#     ('pages', '693--694'),
#     ('year', '2019'),
#     ('organization', 'IEEE')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Sandygulova, Anara'), Person('De Wit, Jan'), Person('De Haas, Mirjam'), Person('Scassellati, Brian')])]))
# SUCESSFULLY PARSED johal2019robots: " Robots for Learning-R4L: Adaptive Learning  "
# ==========
# asselborn2019reply
# Entry('article',
#   fields=[
#     ('title', 'Reply: Limitations in the creation of an automatic diagnosis tool for dysgraphia'),
#     ('journal', 'npj Digital Medicine'),
#     ('volume', '2'),
#     ('number', '1'),
#     ('pages', '37'),
#     ('year', '2019'),
#     ('publisher', 'Nature Publishing Group')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Asselborn, Thibault'), Person('Gargot, Thomas'), Person('Kidzinski, Lukasz'), Person('Johal, Wafa'), Person('Cohen, David'), Person('Jolly, Caroline'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'booktitle' from entry asselborn2019reply: " Reply: Limitations in the crea ... "
# ==========
# zolna2019dynamics
# Entry('misc',
#   fields=[
#     ('title', 'The Dynamics of Handwriting Improves the Automated Diagnosis of Dysgraphia'),
#     ('journal', 'arXiv preprint arXiv:1906.07576'),
#     ('year', '2019')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Zolna, Konrad'), Person('Asselborn, Thibault'), Person('Jolly, Caroline'), Person('Casteran, Laurence'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'booktitle' from entry zolna2019dynamics: " The Dynamics of Handwriting Im ... "
# ==========
# ozgur2019towards
# Entry('inproceedings',
#   fields=[
#     ('title', 'Towards an Adaptive Upper Limb Rehabilitation Game with Tangible Robots'),
#     ('booktitle', '2019 IEEE 16th International Conference on Rehabilitation Robotics (ICORR)'),
#     ('pages', '294--299'),
#     ('year', '2019'),
#     ('organization', 'IEEE')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Ozgur, Arzu Guneysu'), Person('Faucon, Louis P'), Person('Maceira-Elvira, Pablo'), Person('Wessel, Maximilian J'), Person('Johal, Wafa'), Person('{\\"O}zg{\\"u}r, Ayberk'), Person("Cadic-Melchior, And{\\'e}ol"), Person('Hummel, Friedhelm C'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED ozgur2019towards: " Towards an Adaptive Upper Limb Rehabilitation Game with Tang ... "
# ==========
# johal2019learning
# Entry('inproceedings',
#   fields=[
#     ('title', 'Learning Symmetry with Tangible Robots'),
#     ('booktitle', 'International Conference on Robotics and Education RiE 2017'),
#     ('pages', '270--283'),
#     ('year', '2019'),
#     ('organization', 'Springer, Cham')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Andersen, Sonia'), Person('Chevalier, Morgane'), Person('Ozgur, Ayberk'), Person('Mondada, Francesco'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED johal2019learning: " Learning Symmetry with Tangible Robots  "
# ==========
# asselborn2019bridging
# Entry('article',
#   fields=[
#     ('title', 'Bridging Multilevel Time Scales in HRI: An Analysis Framework'),
#     ('journal', 'ACM Transactions on Human-Robot Interaction (THRI)'),
#     ('volume', '8'),
#     ('number', '3'),
#     ('pages', '17'),
#     ('year', '2019'),
#     ('publisher', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Asselborn, Thibault'), Person('Sharma, Kshitij'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'booktitle' from entry asselborn2019bridging: " Bridging Multilevel Time Scale ... "
# ==========
# nasir2019robot
# Entry('inproceedings',
#   fields=[
#     ('title', 'Robot Analytics: What Do Human-Robot Interaction Traces Tell Us About Learning?'),
#     ('booktitle', '[Proceedings of the IEEE RoMan 2019-The 28th IEEE International Conference on Robot \\& Human Interactive Communication]'),
#     ('number', 'CONF'),
#     ('year', '2019')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Nasir, Jauwairia'), Person('Norman, Utku'), Person('Johal, Wafa'), Person('Olsen, Jennifer Kaitlyn'), Person('Shahmoradi, Sina'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED nasir2019robot: " Robot Analytics: What Do Human-Robot Interaction Traces Tell ... "
# ==========
# shahmoradi2019orchestration
# Entry('inproceedings',
#   fields=[
#     ('title', 'Orchestration of Robotic Activities in Classrooms: Challenges and Opportunities'),
#     ('booktitle', 'European Conference on Technology Enhanced Learning'),
#     ('pages', '640--644'),
#     ('year', '2019'),
#     ('organization', 'Springer, Cham')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Shahmoradi, Sina'), Person('Olsen, Jennifer K'), Person('Haklev, Stian'), Person('Johal, Wafa'), Person('Norman, Utku'), Person('Nasir, Jauwairia'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED shahmoradi2019orchestration: " Orchestration of Robotic Activities in Classrooms: Challenge ... "
# ==========
# kim_cowriting_2019
# Entry('inproceedings',
#   fields=[
#     ('title', '{CoWriting} Kazakh: Transitioning to a New Latin Script using Social Robots'),
#     ('pages', '1--6'),
#     ('booktitle', '2019 28th {IEEE} International Conference on Robot and Human Interactive Communication ({RO}-{MAN})'),
#     ('publisher', '{IEEE}'),
#     ('date', '2019')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Kim, Anton'), Person('Omarova, Meruyert'), Person('Zhaksylyk, Adil'), Person('Asselborn, Thibault'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre'), Person('Sandygulova, Anara')])]))
# WARNING Missing Expected Field 'year' from entry kim_cowriting_2019: " {CoWriting} Kazakh: Transition ... "
# ==========
# johal_augmented_2019
# Entry('inproceedings',
#   fields=[
#     ('title', 'Augmented Robotics for Learners: A Case Study on Optics'),
#     ('doi', '10.1109/RO-MAN46459.2019.8956363'),
#     ('shorttitle', 'Augmented Robotics for Learners'),
#     ('abstract', "In recent years, robots have been surfing on a trendy wave as standard devices for teaching programming. The tangibility of robotics platforms allows for collaborative and interactive learning. Moreover, with these robot platforms, we also observe the occurrence of a shift of visual attention from the screen (on which the programming is done) to the physical environments (i.e. the robot). In this paper, we describe an experiment aiming at studying the effect of using augmented reality ({AR}) representations of sensor data in a robotic learning activity. We designed an {AR} system able to display in real-time the data of the Infra-Red sensors of the Thymio robot. In order to evaluate the impact of {AR} on the learner's understanding on how these sensors worked, we designed a pedagogical lesson that can run with or without the {AR} rendering. Two different age groups of students participated in this between-subject experiment, counting a total of 74 children. The tests were the same for the experimental ({AR}) and control group (no {AR}). The exercises differed only through the use of {AR}. Our results show that {AR} was worth being used for younger groups dealing with difficult concepts. We discuss our findings and propose future works to establish guidelines for designing {AR} robotic learning sessions."),
#     ('eventtitle', '2019 28th {IEEE} International Conference on Robot and Human Interactive Communication ({RO}-{MAN})'),
#     ('pages', '1--6'),
#     ('booktitle', '2019 28th {IEEE} International Conference on Robot and Human Interactive Communication ({RO}-{MAN})'),
#     ('date', '2019-10'),
#     ('note', '{ISSN}: 1944-9445'),
#     ('keywords', '{AR} rendering, {AR} robotic learning sessions, {AR} system, augmented reality, Augmented Reality, augmented reality representations, augmented robotics, collaborative learning, computer aided instruction, computer science education, control group, Education, educational robots, experimental group, human-robot interaction, infrared detectors, infrared sensors, interactive learning, interactive systems, Optics, programming, programming teaching, robot platforms, robotic learning activity, Robotics, robotics platforms, sensor data, standard devices, teaching, Thymio robot, trendy wave, visual attention'),
#     ('file', 'IEEE Xplore Abstract Record:/home/wafa/Zotero/storage/9G38MGW9/8956363.html:text/html;IEEE Xplore Full Text PDF:/home/wafa/Zotero/storage/I8I5J5LS/Johal et al. - 2019 - Augmented Robotics for Learners A Case Study on O.pdf:application/pdf')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Robu, Olguta'), Person('Dame, Amaury'), Person('Magnenat, Stephane'), Person('Mondada, Francesco')])]))
# WARNING Missing Expected Field 'year' from entry johal_augmented_2019: " Augmented Robotics for Learner ... "
# ==========
# ozgur_designing_2019
# Entry('inproceedings',
#   fields=[
#     ('title', 'Designing Configurable Arm Rehabilitation Games: How Do Different Game Elements Affect User Motion Trajectories?'),
#     ('pages', '5326--5330'),
#     ('booktitle', '2019 41st Annual International Conference of the {IEEE} Engineering in Medicine and Biology Society ({EMBC})'),
#     ('publisher', '{IEEE}'),
#     ('date', '2019')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Ozgur, Arzu Guneysu'), Person('Wessel, Maximilian J'), Person('Asselborn, Thibault'), Person('Olsen, Jennifer K'), Person('Johal, Wafa'), Person('Ozgur, Ayberk'), Person('Hummel, Friedhelm C'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'year' from entry ozgur_designing_2019: " Designing Configurable Arm Reh ... "
# ==========
# el_hamamsy_learning_2019
# Entry('inproceedings',
#   fields=[
#     ('title', 'Learning By Collaborative Teaching: An Engaging Multi-Party {CoWriter} Activity'),
#     ('pages', '1--8'),
#     ('booktitle', '2019 28th {IEEE} International Conference on Robot and Human Interactive Communication ({RO}-{MAN})'),
#     ('publisher', '{IEEE}'),
#     ('date', '2019')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('El Hamamsy, Laila'), Person('Johal, Wafa'), Person('Asselborn, Thibault'), Person('Nasir, Jauwairia'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'year' from entry el_hamamsy_learning_2019: " Learning By Collaborative Teac ... "
# ==========
# yadollahi_studying_2019
# Entry('inproceedings',
#   fields=[
#     ('title', "Studying the Effect of Robot Frustration on Children's Change of Perspective"),
#     ('pages', '381--387'),
#     ('booktitle', '2019 8th International Conference on Affective Computing and Intelligent Interaction Workshops and Demos ({ACIIW})'),
#     ('publisher', '{IEEE}'),
#     ('date', '2019')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Yadollahi, Elmira'), Person('Johal, Wafa'), Person('Dias, Joao'), Person('Dillenbourg, Pierre'), Person('Paiva, Ana')])]))
# WARNING Missing Expected Field 'year' from entry yadollahi_studying_2019: " Studying the Effect of Robot F ... "
# ==========
# zhanel-hri2020-video
# Entry('inproceedings',
#   fields=[
#     ('bo
#     oktitle', '2020 ACM/IEEE International Conference on Human-Robot Interaction (HRI)'),
#     ('organization', 'ACM'), ('title', 'CoWriting Kazakh: Learning a New Script with a Robot - Video'),
#     ('year', '2020')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Zhexenova, Zhanel'), Person('Tleubayev, Bolat'), Person('Zhanatkyzy, Aida'), Person('Turarova, Aizada'), Person('Telisheva, Zhansaule'), Person('Johal, Wafa'), Person('Asselborn, Thibault'), Person('Dillenbourg, Pierre'), Person('Sandygulova, Anara')])]))
# SUCESSFULLY PARSED zhanel-hri2020-video: " CoWriting Kazakh: Learning a New Script with a Robot - Video  "
# ==========
# sandygulova-hri2020
# Entry('inproceedings',
#   fields=[
#     ('bo
#     oktitle', '2020 ACM/IEEE International Conference on Human-Robot Interaction (HRI)'),
#     ('organization', 'ACM'), ('title', 'CoWriting Kazakh: Learning a New Script with a Robot'),
#     ('year', '2020')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Sandygulova, Anara'), Person('Johal, Wafa'), Person('Zhexenova, Zhanel'), Person('Tleubayev, Bolat'), Person('Zhanatkyzy, Aida'), Person('Turarova, Aizada'), Person('Telisheva, Zhansaule'), Person('CohenMiller, Anna'), Person('Asselborn, Thibault'), Person('Dillenbourg, Pierre')])]))
# SUCESSFULLY PARSED sandygulova-hri2020: " CoWriting Kazakh: Learning a New Script with a Robot  "
# ==========
# guneysu_ozgur_iterative_2020
# Entry('article',
#   fields=[
#     ('title', 'Iterative Design and Evaluation of a Tangible Robot-Assisted Handwriting Activity for Special Education'),
#     ('volume', '7'),
#     ('issn', '2296-9144'),
#     ('url', 'https://www.frontiersin.org/articles/10.3389/frobt.2020.00029/full?utm_source=FRN&utm_medium=EMAIL_IRIS&utm_campaign=EMI_FRN_ARTICLEPUBLISHED_FOLLOWERS&utm_content=ARTICLE_TITLE'),
#     ('doi', '10.3389/frobt.2020.00029'),
#     ('abstract', "In this article, we investigate the role of interactive haptic-enabled tangible robots in supporting the learning of cursive letter writing for children with attention and visuomotor coordination issues. We focus on the two principal aspects of handwriting that are linked to these issues: Visual perception and visuomotor coordination. These aspects respectively enhance two features of letter representation in the learner's mind in particular, namely the shape (grapheme) and the dynamics (ductus) of the letter, which constitute the central learning goals in our activity. Building upon an initial design tested with 17 healthy children in a preliminary school, we iteratively ported the activity to an occupational therapy context in 2 different therapy centers, in the context of 3 different summer school camps involving a total of 12 children having writing difficulties. The various iterations allowed us to uncover insights about the design of robot-enhanced writing activities for special education, specifically highlighting the importance of ease of modification of the duration of an activity as well as of adaptable frequency, content, flow, and game-play and of providing a range of evaluation test alternatives. Results show that the use of robot-assisted handwriting activities could have a positive impact on the learning of the representation of letters in the context of occupational therapy (V = 1449, p {\\textless} 0.001, r=0.42). Results also highlight how the design changes made across the iterations affected the outcomes of the handwriting sessions, such as the evaluation of the performances, monitoring of the performances, and the connectedness of the handwriting."),
#     ('journaltitle', 'Frontiers in Robotics and {AI}'),
#     ('shortjournal', 'Front. Robot. {AI}'),
#     ('u
#     rldate', '2020-03-06'), ('date', '2020'),
#     ('note', 'Publisher: Frontiers'),
#     ('keywords', 'tangible robots, handwriting, Gamified activities, Haptic interface, interactive learning environments, iterative design, Occupational thearpy, Robots for education'),
#     ('file', 'Full Text PDF:/home/wafa/Zotero/storage/4DLA3VPQ/Guneysu Ozgur et al. - 2020 - Iterative Design and Evaluation of a Tangible Robo.pdf:application/pdf')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Guneysu Ozgur, Arzu'), Person('Özgür, Ayberk'), Person('Asselborn, Thibault'), Person('Johal, Wafa'), Person('Yadollahi, Elmira'), Person('Bruno, Barbara'), Person('Skweres, Melissa'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'year' from entry guneysu_ozgur_iterative_2020: " Iterative Design and Evaluatio ... "
# ==========
# guneysu_ozgur_gamified_2020
# Entry('article',
#   fields=[
#     ('title', 'Gamified Motor Training with Tangible Robots in Older Adults: a Feasibility Study and Comparison with Young'),
#     ('volume', '12'),
#     ('issn', '1663-4365'),
#     ('url', 'https://www.frontiersin.org/articles/10.3389/fnagi.2020.0005
#     9/abstract'),
#     ('doi', '10.3389/fnagi.2020.00059'),
#     ('shorttitle', 'Gamified Motor Training with Tangible Robots in Older Adults'), ('abstract', 'Background: The increasing lifespan and the resulting change of our expectations in later life stages are dependent on a good health state. This emphasizes the development of strategies to further healthy ageing. One important aspect of good health in later life stages is sustained skilled motor function. Objective: Here, we tested the effectiveness of robotic upper limb motor training in a game-like scenario assessing game-based learning and its transfer potential. Methods: Thirty-six healthy participants (n = 18 elderly participants, n = 18 young controls) trained with a Pacman-like game using a hand-held Cellulo robot on two consecutive days. The game-related movements were conducted on a printed map displaying a maze and targets that had to be collected. Gradually, the task difficulty was adjusted between games by modifying or adding different game elements (e.g., speed and number of chasing ghosts, additional rules, haptic feedback). Transfer was assessed by scoring simple robot manipulation on two different trajectories. Results: Elderly participants were able to improve their game performance over time (t(874) = 2.97, p {\\textless} .01). The applied game-elements had similar effects on both age groups. Importantly, the game-based learning transferred to simple robot manipulation, which resembles activities of daily life. Only minor age-related differences were present (smaller overall learning gain, different effect of the wall crash penalty rule in the elderly group). Conclusions: Gamified motor training with the Cellulo system has the potential to translate into an efficient, relatively low-cost robotic motor training tool for promoting upper limb function to promote healthy aging.'),
#     ('journaltitle', 'Frontiers in Aging Neuroscience'),
#     ('shortjournal', 'Front. Aging Neurosci.'),
#     ('u
#     rldate', '2020-03-06'), ('date', '2020'),
#     ('note', 'Publisher: Frontiers'),
#     ('keywords', 'tangible robots, Task Performance and Analysis, Aging, Gamified activities, Healthy Ageing, motor learning, Robotic exercise, Transfer Learning')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Guneysu Ozgur, Arzu'), Person('Wessel, Maximilian Jonas'), Person('Olsen, Jennifer Kaitlyn'), Person('Johal, Wafa'), Person('Özgür, Ayberk'), Person('Hummel, Friedhelm C.'), Person('Dillenbourg, Pierre')])]))
# WARNING Missing Expected Field 'year' from entry guneysu_ozgur_gamified_2020: " Gamified Motor Training with T ... "
# ==========
# Ioannou_learning_2020
# Entry('inproceedings',
#   fields=[
#     ('title', 'Learning (Good Handwriting in Greek) by Teaching (a Humanoid Robot)'),
#     ('series', '14th International Technology, Education and Development Conference'),
#     ('booktitle', 'INTED2020 Proceedings'),
#     ('isbn', '978-84-09-17939-8'),
#     ('issn', '2340-1079'),
#     ('doi', '10.21125/inted.2020.1926'),
#     ('url', 'http://dx.doi.org/10.21125/inted.2020.1926'),
#     ('publisher', 'IATED'),
#     ('location', 'Valencia, Spain'),
#     ('year', '2020'),
#     ('pages', '7287-7296')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Ioannou, C.'), Person('Neophytou, C.'), Person('Asselborn, T.'), Person('Johal, W.'), Person('Hadzilacos, T.')])]))
# SUCESSFULLY PARSED Ioannou_learning_2020: " Learning (Good Handwriting in Greek) by Teaching (a Humanoid ... "
# ==========
# neto_using_2020
# Entry('inproceedings',
#   fields=[
#     ('series', "{IDC} '20"),
#     ('title', 'Using Tabletop Robots to promote Inclusive Classroom Experiences'),
#     ('url', 'https:
#     //doi.org/10.1145/3392063.3394439'), ('doi', '10.1145/3392063.3394439'),
#     ('booktitle', 'Proceedings of the 19th {ACM} {Conference} on {Interaction} {Design} and {Children}'),
#     ('publisher', 'Association for Computing Machinery'),
#     ('month', 'June'),
#     ('year', '2020'),
#     ('keywords', 'child robot interaction, deictic gestures, education, learning by teaching, pointing, protégé effect, reading')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Neto, Isabel'), Person('Johal, Wafa'), Person('Couto, Marta'), Person('Nicolau, Hugo'), Person('Paiva, Ana'), Person('Guneysu, Arzu')])]))
# SUCESSFULLY PARSED neto_using_2020: " Using Tabletop Robots to promote Inclusive Classroom Experie ... "
# ==========
# johal2020research
# Entry('article',
#   fields=[
#     ('title', 'Research Trends in Social Robots for Learning'),
#     ('journal', 'Current Robotics Reports'),
#     ('pages', '1--9'),
#     ('year', '2020'),
#     ('publisher', 'Springer International Publishing')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa')])]))
# WARNING Missing Expected Field 'booktitle' from entry johal2020research: " Research Trends in Social Robo ... "
# ==========
# yadollahi2020exploring
# Entry('inproceedings',
#   fields=[
#     ('title', 'Exploring the Role of Perspective Taking in Educational Child-Robot Interaction'),
#     ('booktitle', 'International Conference on Artificial Intelligence in Education'),
#     ('pages', '346--351'),
#     ('year', '2020'),
#     ('organization', 'Springer, Cham')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Yadollahi, Elmira'), Person('Couto, Marta'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre'), Person('Paiva, Ana')])]))
# SUCESSFULLY PARSED yadollahi2020exploring: " Exploring the Role of Perspective Taking in Educational Chil ... "
# ==========
# gargot2020acquisition
# Entry('article',
#   fields=[
#     ('title', 'Acquisition of handwriting in children with and without dysgraphia: A computational approach'),
#     ('journal', 'Plos one'),
#     ('volume', '15'),
#     ('number', '9'),
#     ('pages', 'e0237575'),
#     ('year', '2020'),
#     ('publisher', 'Public Library of Science San Francisco, CA USA')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Gargot, Thomas'), Person('Asselborn, Thibault'), Person('Pellerin, Hugues'), Person('Zammouri, Ingrid'), Person('M. Anzalone, Salvatore'), Person('Casteran, Laurence'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre'), Person('Cohen, David'), Person('Jolly, Caroline')])]))
# WARNING Missing Expected Field 'booktitle' from entry gargot2020acquisition: " Acquisition of handwriting in  ... "
# ==========
# johal2020Swarm
# Entry('inproceedings',
#   fields=[
#     ('title', 'Swarm Robots in Education: A Review of Challenges and Opportunities'),
#     ('year', '2020'),
#     ('isbn', '9781450380546'),
#     ('publisher', 'Association for Computing Machinery'),
#     ('address', 'New York, NY, USA'),
#     ('url', 'https:
#     //doi.org/10.1145/3406499.3418755'), ('doi', '10.1145/3406499.3418755'),
#     ('abstract', 'This study reviews published scientific literature on the use of swarm robots for education purposes in the last ten years. It focuses on user studies involving robotics swarm in order to identify the potential contributions of the incorporation of swarm robots as an educational tool and insight future research. We consider here the appearance of swarm robots, the curriculum of the experimental task and the interaction modalities between learners and robots. The outcomes of the literature review are discussed in terms of their existing challenges and opportunities for guiding researchers, educators, and practitioners.'),
#     ('booktitle', 'Proceedings of the 8th International Conference on Human-Agent Interaction'),
#     ('pages', '272–274'),
#     ('numpages', '3'),
#     ('keywords', 'educational tool, swarm robots, literature review, learning, multi-robot'),
#     ('location', 'Virtual Event, USA'),
#     ('series', "HAI '20")],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Peng, Yu'), Person('Mi, Haipeng')])]))
# SUCESSFULLY PARSED johal2020Swarm: " Swarm Robots in Education: A Review of Challenges and Opport ... "
# ==========
# gargot2020p
# Entry('article',
#   fields=[
#     ('title', 'P. 114 Automatic assessment of motors impairments in autism spectrum disorders: a systematic review'),
#     ('journal', 'European Neuropsychopharmacology'),
#     ('volume', '40'),
#     ('pages', 'S71--S72'),
#     ('year', '2020'),
#     ('publisher', 'Elsevier')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Gargot, T'), Person('Archambault, D'), Person('Chetouani, M'), Person('Cohen, D'), Person('Johal, W'), Person('Anzalone, SM')])]))
# WARNING Missing Expected Field 'booktitle' from entry gargot2020p: " P. 114 Automatic assessment of ... "
# ==========
# chibaudel2020
# Entry('inproceedings',
#   fields=[
#     ('title', '"If You\'ve Gone Straight, Now, You Must Turn Left" - Exploring the Use of a Tangible Interface in a Collaborative Treasure Hunt for People with Visual Impairments'),
#     ('year', '2020'),
#     ('isbn', '9781450371032'),
#     ('publisher', 'Association for Computing Machinery'),
#     ('address', 'New York, NY, USA'),
#     ('url', 'https:
#     //doi.org/10.1145/3373625.3417020'), ('doi', '10.1145/3373625.3417020'),
#     ('abstract', 'Tangible User Interfaces (TUI) have been found to be relevant tools for collaborative learning by providing a shared workspace and enhancing joint visual attention. Researchers have explored the use of TUIs in a variety of curricular activities and found them particularly interesting for spatial exploration. However, very few studies have explored how TUIs could be used as a collaborative medium for people with visual impairments (VIs). In this study, we investigated the effect of tangible interaction (a small tangible robot) in a spatial collaborative task (a treasure hunt) involving two people with VIs. The aim was to evaluate the impact of the design of the TUI on the collaboration and the strategies used to perform the task. The experiment involved six dyads of people with VIs. The results showed that the collaboration was impacted by the interaction design and open interesting perspectives on the design of collaborative games for people with VIs.'),
#     ('booktitle', 'The 22nd International ACM SIGACCESS Conference on Computers and Accessibility'),
#     ('articleno', '19'),
#     ('numpages', '10'),
#     ('keywords', 'Spatial cognition, Game, Wayfinding, Robots, Non-visual interaction, Maps, Learning, Haptics, 3D model'),
#     ('location', 'Virtual Event, Greece'),
#     ('series', "ASSETS '20")],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Chibaudel, Quentin'), Person('Johal, Wafa'), Person('Oriola, Bernard'), Person("J-M Mac\\'{e}, Marc"), Person('Dillenbourg, Pierre'), Person("Tartas, Val\\'{e}rie"), Person('Jouffrais, Christophe')])]))
# SUCESSFULLY PARSED chibaudel2020: " "If You've Gone Straight, Now, You Must Turn Left" - Explori ... "
# ==========
# zhanel2020
# Entry('article',
#   fields=[
#     ('TITLE', 'A Comparison of Social Robot to Tablet and Teacher in a New Script Learning Context'),
#     ('JOURNAL', 'Frontiers in Robotics and AI'),
#     ('VOLUME', '7'),
#     ('PAGES', '99'),
#     ('YEAR', '2020'),
#     ('URL', 'https://www.frontiersin.org/article/10.3389/frobt.2020.00099'),
#     ('DOI', '10.3389/frobt.2020.00099'),
#     ('ISSN', '2296-9144'),
#     ('ABSTRACT', 'This research occurred in a special context where Kazakhstan\'s recent decision to switch from Cyrillic to the Latin-based alphabet has resulted in challenges connected to teaching literacy, addressing a rare combination of research hypotheses and technical objectives about language learning. Teachers are not necessarily trained to teach the new alphabet, and this could result in a challenge for children with learning difficulties. Prior research studies in Human-Robot Interaction (HRI) have proposed the use of a robot to teach handwriting to children (Hood et al., <xref ref-type="bibr" rid="B28">2015</xref>; Lemaignan et al., <xref ref-type="bibr" rid="B44">2016</xref>). Drawing on the Kazakhstani case, our study takes an interdisciplinary approach by bringing together smart solutions from robotics, computer vision areas, and educational frameworks, language, and cognitive studies that will benefit diverse groups of stakeholders. In this study, a human-robot interaction application is designed to help primary school children learn both a newly-adopted script and also its handwriting system. The setup involved an experiment with 62 children between the ages of 7–9 years old, across three conditions: a robot and a tablet, a tablet only, and a teacher. Based on the paradigm—learning by teaching—the study showed that children improved their knowledge of the Latin script by interacting with a robot. Findings reported that children gained similar knowledge of a new script in all three conditions without gender effect. In addition, children\'s likeability ratings and positive mood change scores demonstrate significant benefits favoring the robot over a traditional teacher and tablet only approaches.')],
#   persons=OrderedCaseInsensitiveDict([('AUTHOR', [Person('Zhexenova, Zhanel'), Person('Amirova, Aida'), Person('Abdikarimova, Manshuk'), Person('Kudaibergenov, Kuanysh'), Person('Baimakhan, Nurakhmet'), Person('Tleubayev, Bolat'), Person('Asselborn, Thibault'), Person('Johal, Wafa'), Person('Dillenbourg, Pierre'), Person('CohenMiller, Anna'), Person('Sandygulova, Anara')])]))
# WARNING Missing Expected Field 'booktitle' from entry zhanel2020: " A Comparison of Social Robot t ... "
# ==========
# ingle2021
# Entry('inproceedings',
#   fields=[
#     ('title', "The Valley of non-Distraction: Effect of Robot's Human-likeness on Perception Load"),
#     ('year', '2021'),
#     ('booktitle', "Companion of the 2021 ACM/IEEE International Conference on Human-Robot Interaction (HRI '21 Companion), March 8--11, 2021, Boulder,CO, USA"),
#     ('publisher', 'Association for Computing Machinery'),
#     ('abstract', '"Previous research in psychology has found that human faces have the capability of being more distracting under high perceptual load conditions compared to non-face objects. This project aims to assess the distracting potential of robot faces based on their human-likeliness. As a first step, this paper reports on our initial findings based on an online study. We used a letter search task where participants had to search for a target letter within a circle of 6 letters, whilst an irrelevant distractor image was also present. The results of our experiment replicated previous results with human faces and non-face objects. Additionally, in the tasks where the irrelevant distractors are images of robot faces, the human-likeness of the robot influenced the response time (RT). Interestingly, the robot Alter produced results significantly different than all other distractor robots. The outcome of this is a distraction model related to human-likeness of robots. Our results show the impact of anthropomorphism on distracting potential and thus should be taken into account when designing robots."'),
#     ('keywords', 'anthropomorphism, robot design, human-likeness, perception load'),
#     ('doi', '10.1145/3434074.3447137')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Ingle, Daisy'), Person('Marcus, Nadine'), Person('Johal, Wafa')])]))
# SUCESSFULLY PARSED ingle2021: " The Valley of non-Distraction: Effect of Robot's Human-liken ... "
# ==========
# phaijit2022let
# Entry('inproceedings',
#   fields=[
#     ('title', 'Let’s Compete! The Influence of Human-Agent Competition and Collaboration on Agent Learning and Human Perception'),
#     ('booktitle', 'Proceedings of the 10th International Conference on Human-Agent Interaction'),
#     ('pages', '86--94'),
#     ('year', '2022')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Phaijit, Ornnalin'), Person('Sammut, Claude'), Person('Johal, Wafa')])]))
# SUCESSFULLY PARSED phaijit2022let: " Let’s Compete! The Influence of Human-Agent Competition and  ... "
# ==========
# bartneck2022proceedings
# Entry('misc',
#   fields=[
#     ('title', 'Proceedings of the 10th International Conference on Human-Agent Interaction'),
#     ('year', '2022'),
#     ('publisher', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Bartneck, Christoph'), Person('Kanda, Takayuki'), Person('Obaid, Mohammad'), Person('Johal, Wafa')])]))
# WARNING Missing Expected Field 'booktitle' from entry bartneck2022proceedings: " Proceedings of the 10th Intern ... "
# ==========
# tozadore2023robots
# Entry('inproceedings',
#   fields=[
#     ('title', "Robots for Learning 7 (R4L) A Look from Stakeholders' Perspective"),
#     ('booktitle', 'Companion of the 2023 ACM/IEEE International Conference on Human-Robot Interaction'),
#     ('pages', '935--937'),
#     ('year', '2023')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Tozadore, Daniel C'), Person('Nasir, Jauwairia'), Person('Gillet, Sarah'), Person('van den Berghe, Rianne'), Person('Guneysu, Arzu'), Person('Johal, Wafa')])]))
# SUCESSFULLY PARSED tozadore2023robots: " Robots for Learning 7 (R4L) A Look from Stakeholders' Perspe ... "
# ==========
# bruno2023culture
# Entry('incollection',
#   fields=[
#     ('title', 'Culture in Social Robots for Education'),
#     ('booktitle', 'Cultural Robotics: Social Robots and Their Emergent Cultural Ecologies'),
#     ('pages', '127--145'),
#     ('year', '2023'),
#     ('publisher', 'Springer International Publishing Cham')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Bruno, Barbara'), Person('Amirova, Aida'), Person('Sandygulova, Anara'), Person('Lugrin, Birgit'), Person('Johal, Wafa')])]))
# SUCESSFULLY PARSED bruno2023culture: " Culture in Social Robots for Education  "
# ==========
# ogawa2021proceedings
# Entry('misc',
#   fields=[
#     ('title', 'Proceedings of the 9th International Conference on Human-Agent Interaction'),
#     ('year', '2021'),
#     ('publisher', 'ACM')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Ogawa, Kohei'), Person('Yonezawa, Tomoko'), Person('Lucas, Gale M'), Person('Osawa, Hirotaka'), Person('Johal, Wafa'), Person('Shiomi, Masahiro')])]))
# WARNING Missing Expected Field 'booktitle' from entry ogawa2021proceedings: " Proceedings of the 9th Interna ... "
# ==========
# liu2023speech
# Entry('inproceedings',
#   fields=[
#     ('title', 'Speech-Gesture GAN: Gesture Generation for Robots and Embodied Agents'),
#     ('booktitle', '2023 32nd IEEE International Conference on Robot and Human Interactive Communication (RO-MAN)'),
#     ('pages', '405--412'),
#     ('year', '2023'),
#     ('organization', 'IEEE')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Liu, Carson Yu'), Person('Mohammadi, Gelareh'), Person('Song, Yang'), Person('Johal, Wafa')])]))
# SUCESSFULLY PARSED liu2023speech: " Speech-Gesture GAN: Gesture Generation for Robots and Embodi ... "
# ==========
# phaijit2023user
# Entry('inproceedings',
#   fields=[
#     ('title', 'User Interface Interventions for Improving Robot Learning from Demonstration'),
#     ('booktitle', 'Proceedings of the 11th International Conference on Human-Agent Interaction'),
#     ('pages', '152--161'),
#     ('year', '2023')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Phaijit, Ornnalin'), Person('Sammut, Claude'), Person('Johal, Wafa')])]))
# SUCESSFULLY PARSED phaijit2023user: " User Interface Interventions for Improving Robot Learning fr ... "
# ==========
# gamboa2023championing
# Entry('inproceedings',
#   fields=[
#     ('title', 'Championing Design Knowledge in Human-Drone Interaction Research'),
#     ('booktitle', 'Proceedings of the 11th International Conference on Human-Agent Interaction'),
#     ('pages', '365--368'),
#     ('year', '2023')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Gamboa, Mafalda'), Person('Ljungblad, Sara'), Person('Johal, Wafa'), Person('Mubin, Omar'), Person('Obaid, Mohammad')])]))
# SUCESSFULLY PARSED gamboa2023championing: " Championing Design Knowledge in Human-Drone Interaction Rese ... "
# ==========
# johal2022envisioning
# Entry('article',
#   fields=[
#     ('title', 'Envisioning social drones in education'),
#     ('journal', 'Frontiers in Robotics and AI'),
#     ('volume', '9'),
#     ('pages', '666736'),
#     ('year', '2022'),
#     ('publisher', 'Frontiers')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Gatos, Do{\\u{g}}a'), Person('Yantac, Asim Evren'), Person('Obaid, Mohammad')])]))
# WARNING Missing Expected Field 'booktitle' from entry johal2022envisioning: " Envisioning social drones in e ... "
# ==========
# obaid2022social
# Entry('inproceedings',
#   fields=[
#     ('title', 'Social Drones for Health and Well-being'),
#     ('booktitle', 'Adjunct Proceedings of the 2022 Nordic Human-Computer Interaction Conference'),
#     ('pages', '1--4'),
#     ('year', '2022')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Obaid, Mohammad'), Person('Tatar, K{\\i}van{\\c{c}}'), Person('Wiberg, Mikael'), Person('Said, Alan'), Person('Rost, Mattias'), Person('Weilenmann, Alexandra'), Person('Johal, Wafa'), Person('Eyssel, Friederike')])]))
# SUCESSFULLY PARSED obaid2022social: " Social Drones for Health and Well-being  "
# ==========
# johal2022robots
# Entry('article',
#   fields=[
#     ('title', 'Robots for learning'),
#     ('journal', 'Frontiers in Robotics and AI'),
#     ('volume', '9'),
#     ('pages', '1050658'),
#     ('year', '2022'),
#     ('publisher', 'Frontiers')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Johal, Wafa'), Person('Belpaeme, Tony'), Person('Chetouani, Mohamed')])]))
# WARNING Missing Expected Field 'booktitle' from entry johal2022robots: " Robots for learning  "
# ==========
# ozgur2022effect
# Entry('article',
#   fields=[
#     ('title', 'The effect of gamified robot-enhanced training on motor performance in chronic stroke survivors'),
#     ('journal', 'Heliyon'),
#     ('volume', '8'),
#     ('number', '11'),
#     ('pages', 'e11764'),
#     ('year', '2022'),
#     ('issn', '2405-8440'),
#     ('doi', 'https://doi.org/10.1016/j.heliyon.2022.e11764'),
#     ('url', 'https://www.sciencedirect.com/science/article/pii/S2405844022030523'),
#     ('keywords', 'Gamification, Robotics, Stroke, Motor rehabilitation, Robot-assisted training, Personalization'),
#     ('abstract', "Task-specific training constitutes a core element for evidence-based rehabilitation strategies targeted at improving upper extremity activity after stroke. Its combination with additional treatment strategies and neurotechnology-based solutions could further improve patients' outcomes. Here, we studied the effect of gamified robot-assisted upper limb motor training on motor performance, skill learning, and transfer with respect to a non-gamified control condition with a group of chronic stroke survivors. The results suggest that a gamified training strategy results in more controlled motor performance during the training phase, which is characterized by a higher accuracy (lower deviance), higher smoothness (lower jerk), but slower speed. The responder analyses indicated that mildly impaired patients benefited most from the gamification approach. In conclusion, gamified robot-assisted motor training, which is personalized to the individual capabilities of a patient, constitutes a promising investigational strategy for further improving motor performance after a stroke.")],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Ozgur, Arzu Guneysu'), Person('Wessel, Maximilian J.'), Person('Olsen, Jennifer K.'), Person('Cadic-Melchior, Andéol Geoffroy'), Person('Zufferey, Valérie'), Person('Johal, Wafa'), Person('Dominijanni, Giulia'), Person('Turlan, Jean-Luc'), Person('Mühl, Andreas'), Person('Bruno, Barbara'), Person('Vuadens, Philippe'), Person('Dillenbourg, Pierre'), Person('Hummel, Friedhelm C.')])]))
# WARNING Missing Expected Field 'booktitle' from entry ozgur2022effect: " The effect of gamified robot-e ... "
